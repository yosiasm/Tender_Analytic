# %%
from nltk.tokenize import sent_tokenize, word_tokenize, wordpunct_tokenize
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import pandas as pd
import string
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import normalize 
from yellowbrick.cluster import InterclusterDistance
from yellowbrick.cluster import SilhouetteVisualizer
from sklearn import metrics
import pickle
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.cluster import KMeans

# %%
raw_data_1 = pd.read_csv("./LPSE LKPP + pemenang.csv")

raw_data_1.head(10)
# Out:
#       kode                                        nama_tender  \
# 0  6599119  Tenaga Ahli Data Driven Kegiatan Koordinasi Se...
# 1  6598119  Tenaga Ahli IT Analisa Sistem   Kegiatan Koord...
# 2  6597119  Tenaga Ahli Senior Monitoring dan Evaluasi Str...
# 3  6596119  Tenaga Ahli Senior Perencanaan Strategic Natio...
# 4  6595119  Tenaga Ahli Muda Bidang Energy Policy Kegiatan...
# 5  6594119  Tenaga Ahli Transportasi (Sektor Jalan dan Dar...
# 6  6593119  Tenaga Ahli Muda Transportasi (Sektor Laut) Ke...
# 7  6592119  Tenaga Ahli Muda Transportasi Kegiatan Integra...
# 8  6591119  Tenaga Ahli Muda GIS Kegiatan Koordinasi Strat...
# 9  6590119  Tenaga Ahli Kelembagaan dan Kebijakan Publik K...
#
#                                        instansi  \
# 0  Kementerian Perencanaan Pembangunan Nasional
# 1  Kementerian Perencanaan Pembangunan Nasional
# 2  Kementerian Perencanaan Pembangunan Nasional
# 3  Kementerian Perencanaan Pembangunan Nasional
# 4  Kementerian Perencanaan Pembangunan Nasional
# 5  Kementerian Perencanaan Pembangunan Nasional
# 6  Kementerian Perencanaan Pembangunan Nasional
# 7  Kementerian Perencanaan Pembangunan Nasional
# 8  Kementerian Perencanaan Pembangunan Nasional
# 9  Kementerian Perencanaan Pembangunan Nasional
#
#                        status_tender       hps                          5  \
# 0  Pengumuman Pascakualifikasi [...]    120 Jt  Pascakualifikasi Dua File
# 1  Pengumuman Pascakualifikasi [...]  183,5 Jt  Pascakualifikasi Dua File
# 2  Pengumuman Pascakualifikasi [...]  228,4 Jt  Pascakualifikasi Dua File
# 3  Pengumuman Pascakualifikasi [...]  254,1 Jt  Pascakualifikasi Dua File
# 4  Pengumuman Pascakualifikasi [...]    132 Jt  Pascakualifikasi Dua File
# 5  Pengumuman Pascakualifikasi [...]    204 Jt  Pascakualifikasi Dua File
# 6  Pengumuman Pascakualifikasi [...]  129,9 Jt  Pascakualifikasi Dua File
# 7  Pengumuman Pascakualifikasi [...]    132 Jt  Pascakualifikasi Dua File
# 8  Pengumuman Pascakualifikasi [...]  129,9 Jt  Pascakualifikasi Dua File
# 9  Pengumuman Pascakualifikasi [...]    264 Jt  Pascakualifikasi Dua File
#
#          6         7                                      8  9  ...  11  12  \
# 0  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
# 1  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
# 2  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
# 3  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
# 4  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
# 5  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
# 6  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
# 7  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
# 8  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
# 9  Seleksi  Kualitas  Jasa Konsultansi Perorangan - TA 2020  3  ... NaN NaN
#
#    13  kategori pagu hps_detail nama_pemenang alamat_pemenang npwp_pemenang  \
# 0   0       NaN  NaN        NaN           NaN             NaN           NaN
# 1   0       NaN  NaN        NaN           NaN             NaN           NaN
# 2   0       NaN  NaN        NaN           NaN             NaN           NaN
# 3   0       NaN  NaN        NaN           NaN             NaN           NaN
# 4   0       NaN  NaN        NaN           NaN             NaN           NaN
# 5   0       NaN  NaN        NaN           NaN             NaN           NaN
# 6   0       NaN  NaN        NaN           NaN             NaN           NaN
# 7   0       NaN  NaN        NaN           NaN             NaN           NaN
# 8   0       NaN  NaN        NaN           NaN             NaN           NaN
# 9   0       NaN  NaN        NaN           NaN             NaN           NaN
#
#   penawaran_pemenang
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
#
# [10 rows x 21 columns]

# %%
raw_data_2 = pd.read_csv("./data sirup update.csv")

raw_data_2.head(10)
# Out:
#    Unnamed: 0  idBulan              metode  \
# 0           0       10        E-Purchasing
# 1           1       10        E-Purchasing
# 2           2        4  Pengadaan Langsung
# 3           3        1  Pengadaan Langsung
# 4           4       12  Pengadaan Langsung
# 5           5       12        Tender Cepat
# 6           6       12  Pengadaan Langsung
# 7           7       11              Tender
# 8           8       11        E-Purchasing
# 9           9       11  Pengadaan Langsung
#
#                                                 nama  \
# 0                    Pengadaan Lemari Besi Fireproof
# 1                    Pengadaan Lemari Besi Fireproof
# 2                            Pengadaan Kursi Pejabat
# 3                          Belanja Bahan Pakai Habis
# 4                     Pengadaan Frame Acrilik Poster
# 5                       Pengadaan Malware Detonation
# 6                             Belanja Smart Card PKB
# 7  Pembangunan IPA Kapasitas  50 l/dt SPAM KSPN T...
# 8  Belanja modal pengadaan alat kedokteran umum d...
# 9                 Pengadaan Bahan Operasional Lapang
#
#                                           instansi  \
# 0                             Kementerian Keuangan
# 1                             Kementerian Keuangan
# 2         Pemerintah Daerah Kabupaten Buton Tengah
# 3                     Pemerintah Daerah Kota Depok
# 4                            Kementerian Kesehatan
# 5       Kementerian Hukum Dan Hak Asasi Manusia RI
# 6               Pemerintah Daerah Kabupaten Bantul
# 7  Kementerian Pekerjaan Umum dan Perumahan Rakyat
# 8            Pemerintah Daerah Kabupaten Klungkung
# 9               Kementerian Kelautan Dan Perikanan
#
#                        lokasi                   jenis       waktu  idMetode  \
# 0                           -                  Barang  2023-10-01         9
# 1                           -                  Barang  2023-10-01         9
# 2                           -                  Barang  2023-04-01         8
# 3                           -                  Barang  2021-01-01         8
# 4                           -                  Barang  2020-12-01         8
# 5                           -                  Barang  2020-12-01        14
# 6                           -                  Barang  2020-12-01         8
# 7  Banten-Pandeglang (Kab.),   Pekerjaan Konstruksi,   2020-11-01        13
# 8                           -                  Barang  2020-11-01         9
# 9                           -                  Barang  2020-11-01         8
#
#          id         pagu  idJenisPengadaan  \
# 0  22319671     23000000                 1
# 1  22319671     23000000                 1
# 2  20854093      5000000                 1
# 3  20376353     10513000                 1
# 4  22867952    120000000                 1
# 5  22726379   2000000000                 1
# 6  22764274    250000000                 1
# 7  22742317  47396910000                 0
# 8  22962548      6545000                 1
# 9  22576098     90000000                 1
#
#                                          satuanKerja
# 0  DIREKTORAT JENDERAL PENGELOLAAN PEMBIAYAAN DAN...
# 1  DIREKTORAT JENDERAL PENGELOLAAN PEMBIAYAAN DAN...
# 2  DINAS KOMUNIKASI INFORMATIKA STATISTIK DAN PER...
# 3     DINAS KETAHANAN PANGAN PERTANIAN DAN PERIKANAN
# 4  SEKRETARIAT DIREKTORAT JENDERAL PELAYANAN KESE...
# 5        DIREKTORAT JENDERAL ADMINISTRASI HUKUM UMUM
# 6                                  Dinas Perhubungan
# 7   PELAKSANAAN PRASARANA PERMUKIMAN PROVINSI BANTEN
# 8                                    DINAS KESEHATAN
# 9                 BALAI BUDIDAYA AIR PAYAU SITUBONDO

# %%
factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()

# %%
result_preprocessing_1 = []
result_preprocessing_2 = []
for column in raw_data_1['nama_tender']:
    sentence = column.lower()
    word = word_tokenize(text = sentence)
    result_remove_punctuation = [result for result in word if result not in list(string.punctuation)]
    result_remove_stopwords = [result for result in result_remove_punctuation if not result in stopwords]
    result_remove_stopwords = ' '.join(result_remove_stopwords)
    result_preprocessing_1.append(result_remove_stopwords)
for column in raw_data_2['nama']:
    sentence = column.lower()
    word = word_tokenize(text = sentence)
    result_remove_punctuation = [result for result in word if result not in list(string.punctuation)]
    result_remove_stopwords = [result for result in result_remove_punctuation if not result in stopwords]
    result_remove_stopwords = ' '.join(result_remove_stopwords)
    result_preprocessing_2.append(result_remove_stopwords)

# %%
raw_data_1['preprocessing'] = result_preprocessing_1
raw_data_2['preprocessing'] = result_preprocessing_2

# %%
raw_data_1
# Out:
#          kode                                        nama_tender  \
# 0     6599119  Tenaga Ahli Data Driven Kegiatan Koordinasi Se...
# 1     6598119  Tenaga Ahli IT Analisa Sistem   Kegiatan Koord...
# 2     6597119  Tenaga Ahli Senior Monitoring dan Evaluasi Str...
# 3     6596119  Tenaga Ahli Senior Perencanaan Strategic Natio...
# 4     6595119  Tenaga Ahli Muda Bidang Energy Policy Kegiatan...
# ...       ...                                                ...
# 3445    40119  Pengadaan Working Furniture <span class='label...
# 3446    39119  Pengadaan Living Furniture <span class='label ...
# 3447    36119          PENGADAAN PERALATAN GEROBAK HOME INDUSTRI
# 3448    32119                     Pengadaan Modul Aplikasi - SIB
# 3449    31119  Pengadaan Pencetakan Buku Standar Dokumen Peng...
#
#                                                instansi  \
# 0          Kementerian Perencanaan Pembangunan Nasional
# 1          Kementerian Perencanaan Pembangunan Nasional
# 2          Kementerian Perencanaan Pembangunan Nasional
# 3          Kementerian Perencanaan Pembangunan Nasional
# 4          Kementerian Perencanaan Pembangunan Nasional
# ...                                                 ...
# 3445  Lembaga Kebijakan Pengadaan Barang/Jasa Pemeri...
# 3446  Lembaga Kebijakan Pengadaan Barang/Jasa Pemeri...
# 3447                       Pemerintah Provinsi Bengkulu
# 3448  Lembaga Kebijakan Pengadaan Barang/Jasa Pemeri...
# 3449  Lembaga Kebijakan Pengadaan Barang/Jasa Pemeri...
#
#                           status_tender       hps                           5  \
# 0     Pengumuman Pascakualifikasi [...]    120 Jt   Pascakualifikasi Dua File
# 1     Pengumuman Pascakualifikasi [...]  183,5 Jt   Pascakualifikasi Dua File
# 2     Pengumuman Pascakualifikasi [...]  228,4 Jt   Pascakualifikasi Dua File
# 3     Pengumuman Pascakualifikasi [...]  254,1 Jt   Pascakualifikasi Dua File
# 4     Pengumuman Pascakualifikasi [...]    132 Jt   Pascakualifikasi Dua File
# ...                                 ...       ...                         ...
# 3445               Tender Sudah Selesai  281,8 Jt  Pascakualifikasi Satu File
# 3446               Tender Sudah Selesai  290,2 Jt  Pascakualifikasi Satu File
# 3447               Tender Sudah Selesai  208,3 Jt  Pascakualifikasi Satu File
# 3448               Tender Sudah Selesai    600 Jt  Pascakualifikasi Satu File
# 3449               Tender Sudah Selesai  309,7 Jt  Pascakualifikasi Satu File
#
#                 6                            7  \
# 0         Seleksi                     Kualitas
# 1         Seleksi                     Kualitas
# 2         Seleksi                     Kualitas
# 3         Seleksi                     Kualitas
# 4         Seleksi                     Kualitas
# ...           ...                          ...
# 3445  Lelang Umum  Harga Terendah Sistem Gugur
# 3446  Lelang Umum  Harga Terendah Sistem Gugur
# 3447  Lelang Umum  Harga Terendah Sistem Gugur
# 3448  Lelang Umum  Harga Terendah Sistem Gugur
# 3449  Lelang Umum  Harga Terendah Sistem Gugur
#
#                                           8  9  ...   12  13  \
# 0     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0
# 1     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0
# 2     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0
# 3     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0
# 4     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0
# ...                                     ... ..  ...  ...  ..
# 3445             Pengadaan Barang - TA 2011  1  ...  0.0   0
# 3446             Pengadaan Barang - TA 2011  1  ...  0.0   0
# 3447             Pengadaan Barang - TA 2011  1  ...  0.0   0
# 3448             Pengadaan Barang - TA 2011  1  ...  0.0   0
# 3449                 Jasa Lainnya - TA 2011  1  ...  0.0   0
#
#               kategori               pagu         hps_detail  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
# ...                ...                ...                ...
# 3445  Pengadaan Barang  Rp 281.825.500,00  Rp 281.825.500,00
# 3446  Pengadaan Barang  Rp 290.237.200,00  Rp 290.237.200,00
# 3447               NaN                NaN                NaN
# 3448  Pengadaan Barang  Rp 600.000.000,00  Rp 600.000.000,00
# 3449      Jasa Lainnya  Rp 310.900.000,00  Rp 309.675.300,00
#
#                 nama_pemenang  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 3445     CV.PULAU CANDI UTAMA
# 3446         PT. Desaku Abadi
# 3447                      NaN
# 3448    PT JIREH DATA INTEGRA
# 3449  CV. Karya Bangun Wahana
#
#                                         alamat_pemenang         npwp_pemenang  \
# 0                                                   NaN                   NaN
# 1                                                   NaN                   NaN
# 2                                                   NaN                   NaN
# 3                                                   NaN                   NaN
# 4                                                   NaN                   NaN
# ...                                                 ...                   ...
# 3445  Jl. Kramat Raya No.23 E Lt 1 Senen, Jakarta Pu...  01.626.119.0-023.000
# 3446  Jl. Kedoya Raya No.53, Kedoya Selatan, Kebon J...  01.724.673.7-039.000
# 3447                                                NaN                   NaN
# 3448  KOMPLEK RUKO MEGA GROSIR CEMPAKA MAS BLOK M no...  31.177.558.9-027.000
# 3449  Ruko Modernland Blok AR.1-2 Jln Jend.Sudirman ...  02.038.650.4-416.000
#
#      penawaran_pemenang                                      preprocessing
# 0                   NaN  tenaga ahli data driven kegiatan koordinasi se...
# 1                   NaN  tenaga ahli it analisa sistem kegiatan koordin...
# 2                   NaN  tenaga ahli senior monitoring evaluasi strateg...
# 3                   NaN  tenaga ahli senior perencanaan strategic natio...
# 4                   NaN  tenaga ahli muda bidang energy policy kegiatan...
# ...                 ...                                                ...
# 3445  Rp 226.369.000,00  pengadaan working furniture span class='label ...
# 3446  Rp 251.541.400,00  pengadaan living furniture span class='label l...
# 3447                NaN          pengadaan peralatan gerobak home industri
# 3448  Rp 594.000.000,00                       pengadaan modul aplikasi sib
# 3449  Rp 211.535.500,00  pengadaan pencetakan buku standar dokumen peng...
#
# [3450 rows x 22 columns]

# %%
raw_data_2
# Out:
#       Unnamed: 0  idBulan              metode  \
# 0              0       10        E-Purchasing
# 1              1       10        E-Purchasing
# 2              2        4  Pengadaan Langsung
# 3              3        1  Pengadaan Langsung
# 4              4       12  Pengadaan Langsung
# ...          ...      ...                 ...
# 1430        1430        1        Dikecualikan
# 1431        1431        1              Tender
# 1432        1432        1             Seleksi
# 1433        1433        1        Dikecualikan
# 1434        1434        1        Dikecualikan
#
#                                                    nama  \
# 0                       Pengadaan Lemari Besi Fireproof
# 1                       Pengadaan Lemari Besi Fireproof
# 2                               Pengadaan Kursi Pejabat
# 3                             Belanja Bahan Pakai Habis
# 4                        Pengadaan Frame Acrilik Poster
# ...                                                 ...
# 1430  Belanja Jasa Akomodasi Pelatihan Imam Masjid A...
# 1431     Belanja Modal Pengadaan Alat Pemadam Kebakaran
# 1432                           Review pola PSDA Tahap 1
# 1433      Belanja Jasa Akomodasi Imam Masjid Angkatan V
# 1434     Belanja Jasa Akomodasi Imam Masjid Angkatan IV
#
#                                              instansi  \
# 0                                Kementerian Keuangan
# 1                                Kementerian Keuangan
# 2            Pemerintah Daerah Kabupaten Buton Tengah
# 3                        Pemerintah Daerah Kota Depok
# 4                               Kementerian Kesehatan
# ...                                               ...
# 1430        Pemerintah Daerah Provinsi Sumatera Barat
# 1431      Pemerintah Daerah Provinsi Kalimantan Timur
# 1432  Kementerian Pekerjaan Umum dan Perumahan Rakyat
# 1433        Pemerintah Daerah Provinsi Sumatera Barat
# 1434        Pemerintah Daerah Provinsi Sumatera Barat
#
#                                lokasi               jenis       waktu  \
# 0                                   -              Barang  2023-10-01
# 1                                   -              Barang  2023-10-01
# 2                                   -              Barang  2023-04-01
# 3                                   -              Barang  2021-01-01
# 4                                   -              Barang  2020-12-01
# ...                               ...                 ...         ...
# 1430                                -        Jasa Lainnya  2020-01-01
# 1431  Kalimantan Timur-Paser (Kab.),             Barang,   2020-01-01
# 1432      Jawa Barat-Bandung (Kota),   Jasa Konsultansi,   2020-01-01
# 1433                                -        Jasa Lainnya  2020-01-01
# 1434                                -        Jasa Lainnya  2020-01-01
#
#       idMetode        id       pagu  idJenisPengadaan  \
# 0            9  22319671   23000000                 1
# 1            9  22319671   23000000                 1
# 2            8  20854093    5000000                 1
# 3            8  20376353   10513000                 1
# 4            8  22867952  120000000                 1
# ...        ...       ...        ...               ...
# 1430        16  22421624   56000000                 4
# 1431        13  22139846  938000000                 0
# 1432        15  22744714  494680000                 0
# 1433        16  22424242   56000000                 4
# 1434        16  22424197   56000000                 4
#
#                                             satuanKerja  \
# 0     DIREKTORAT JENDERAL PENGELOLAAN PEMBIAYAAN DAN...
# 1     DIREKTORAT JENDERAL PENGELOLAAN PEMBIAYAAN DAN...
# 2     DINAS KOMUNIKASI INFORMATIKA STATISTIK DAN PER...
# 3        DINAS KETAHANAN PANGAN PERTANIAN DAN PERIKANAN
# 4     SEKRETARIAT DIREKTORAT JENDERAL PELAYANAN KESE...
# ...                                                 ...
# 1430  BIRO BINA MENTAL DAN KESEJAHTERAAN RAKYAT SETD...
# 1431                                    Dinas Kehutanan
# 1432                 BALAI BESAR WILAYAH SUNGAI CITARUM
# 1433  BIRO BINA MENTAL DAN KESEJAHTERAAN RAKYAT SETD...
# 1434  BIRO BINA MENTAL DAN KESEJAHTERAAN RAKYAT SETD...
#
#                                           preprocessing
# 0                       pengadaan lemari besi fireproof
# 1                       pengadaan lemari besi fireproof
# 2                               pengadaan kursi pejabat
# 3                             belanja bahan pakai habis
# 4                        pengadaan frame acrilik poster
# ...                                                 ...
# 1430  belanja jasa akomodasi pelatihan imam masjid a...
# 1431     belanja modal pengadaan alat pemadam kebakaran
# 1432                           review pola psda tahap 1
# 1433      belanja jasa akomodasi imam masjid angkatan v
# 1434     belanja jasa akomodasi imam masjid angkatan iv
#
# [1435 rows x 14 columns]

# %% [markdown]
# # Raw Data 1 - LPSE LKPP

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_weights_matrix = tfidf_vectorizer.fit_transform(raw_data_1['preprocessing'])
lda = LDA(n_components=20,n_jobs=-1)
lda_output = lda.fit_transform(tfidf_weights_matrix)
scaler = StandardScaler()
vectorScaler = scaler.fit_transform(lda_output)
vectorNormalize = normalize(vectorScaler)

# %%
kmeans_obj = KMeans(n_clusters=25, random_state=50)
kmeans_obj.fit(vectorNormalize)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=25, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=50, tol=0.0001, verbose=0)

# %%
visualizer_kmeans = InterclusterDistance(kmeans_obj, random_state = 50)
visualizer_kmeans.fit(vectorNormalize)
visualizer_kmeans.finalize()

# %%
visualizer_kmeans_silhouette = SilhouetteVisualizer(kmeans_obj, color='yellowbrick')
visualizer_kmeans_silhouette.fit(vectorNormalize)
visualizer_kmeans_silhouette.show()

# %%
labels = kmeans_obj.labels_
silhouette_score = metrics.silhouette_score(vectorNormalize, labels, metric='euclidean')
silhouette_score
# Out:
# 0.5558507130307709

# %%
result_clustering = kmeans_obj.predict(vectorNormalize)

# %%
raw_data_1['kategori'] = result_clustering
raw_data_1
# Out:
#          kode                                        nama_tender  \
# 0     6599119  Tenaga Ahli Data Driven Kegiatan Koordinasi Se...
# 1     6598119  Tenaga Ahli IT Analisa Sistem   Kegiatan Koord...
# 2     6597119  Tenaga Ahli Senior Monitoring dan Evaluasi Str...
# 3     6596119  Tenaga Ahli Senior Perencanaan Strategic Natio...
# 4     6595119  Tenaga Ahli Muda Bidang Energy Policy Kegiatan...
# ...       ...                                                ...
# 3445    40119  Pengadaan Working Furniture <span class='label...
# 3446    39119  Pengadaan Living Furniture <span class='label ...
# 3447    36119          PENGADAAN PERALATAN GEROBAK HOME INDUSTRI
# 3448    32119                     Pengadaan Modul Aplikasi - SIB
# 3449    31119  Pengadaan Pencetakan Buku Standar Dokumen Peng...
#
#                                                instansi  \
# 0          Kementerian Perencanaan Pembangunan Nasional
# 1          Kementerian Perencanaan Pembangunan Nasional
# 2          Kementerian Perencanaan Pembangunan Nasional
# 3          Kementerian Perencanaan Pembangunan Nasional
# 4          Kementerian Perencanaan Pembangunan Nasional
# ...                                                 ...
# 3445  Lembaga Kebijakan Pengadaan Barang/Jasa Pemeri...
# 3446  Lembaga Kebijakan Pengadaan Barang/Jasa Pemeri...
# 3447                       Pemerintah Provinsi Bengkulu
# 3448  Lembaga Kebijakan Pengadaan Barang/Jasa Pemeri...
# 3449  Lembaga Kebijakan Pengadaan Barang/Jasa Pemeri...
#
#                           status_tender       hps                           5  \
# 0     Pengumuman Pascakualifikasi [...]    120 Jt   Pascakualifikasi Dua File
# 1     Pengumuman Pascakualifikasi [...]  183,5 Jt   Pascakualifikasi Dua File
# 2     Pengumuman Pascakualifikasi [...]  228,4 Jt   Pascakualifikasi Dua File
# 3     Pengumuman Pascakualifikasi [...]  254,1 Jt   Pascakualifikasi Dua File
# 4     Pengumuman Pascakualifikasi [...]    132 Jt   Pascakualifikasi Dua File
# ...                                 ...       ...                         ...
# 3445               Tender Sudah Selesai  281,8 Jt  Pascakualifikasi Satu File
# 3446               Tender Sudah Selesai  290,2 Jt  Pascakualifikasi Satu File
# 3447               Tender Sudah Selesai  208,3 Jt  Pascakualifikasi Satu File
# 3448               Tender Sudah Selesai    600 Jt  Pascakualifikasi Satu File
# 3449               Tender Sudah Selesai  309,7 Jt  Pascakualifikasi Satu File
#
#                 6                            7  \
# 0         Seleksi                     Kualitas
# 1         Seleksi                     Kualitas
# 2         Seleksi                     Kualitas
# 3         Seleksi                     Kualitas
# 4         Seleksi                     Kualitas
# ...           ...                          ...
# 3445  Lelang Umum  Harga Terendah Sistem Gugur
# 3446  Lelang Umum  Harga Terendah Sistem Gugur
# 3447  Lelang Umum  Harga Terendah Sistem Gugur
# 3448  Lelang Umum  Harga Terendah Sistem Gugur
# 3449  Lelang Umum  Harga Terendah Sistem Gugur
#
#                                           8  9  ...   12  13  kategori  \
# 0     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0         4
# 1     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0         3
# 2     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0         3
# 3     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0         3
# 4     Jasa Konsultansi Perorangan - TA 2020  3  ...  NaN   0         4
# ...                                     ... ..  ...  ...  ..       ...
# 3445             Pengadaan Barang - TA 2011  1  ...  0.0   0        19
# 3446             Pengadaan Barang - TA 2011  1  ...  0.0   0        10
# 3447             Pengadaan Barang - TA 2011  1  ...  0.0   0         9
# 3448             Pengadaan Barang - TA 2011  1  ...  0.0   0         3
# 3449                 Jasa Lainnya - TA 2011  1  ...  0.0   0         1
#
#                    pagu         hps_detail            nama_pemenang  \
# 0                   NaN                NaN                      NaN
# 1                   NaN                NaN                      NaN
# 2                   NaN                NaN                      NaN
# 3                   NaN                NaN                      NaN
# 4                   NaN                NaN                      NaN
# ...                 ...                ...                      ...
# 3445  Rp 281.825.500,00  Rp 281.825.500,00     CV.PULAU CANDI UTAMA
# 3446  Rp 290.237.200,00  Rp 290.237.200,00         PT. Desaku Abadi
# 3447                NaN                NaN                      NaN
# 3448  Rp 600.000.000,00  Rp 600.000.000,00    PT JIREH DATA INTEGRA
# 3449  Rp 310.900.000,00  Rp 309.675.300,00  CV. Karya Bangun Wahana
#
#                                         alamat_pemenang         npwp_pemenang  \
# 0                                                   NaN                   NaN
# 1                                                   NaN                   NaN
# 2                                                   NaN                   NaN
# 3                                                   NaN                   NaN
# 4                                                   NaN                   NaN
# ...                                                 ...                   ...
# 3445  Jl. Kramat Raya No.23 E Lt 1 Senen, Jakarta Pu...  01.626.119.0-023.000
# 3446  Jl. Kedoya Raya No.53, Kedoya Selatan, Kebon J...  01.724.673.7-039.000
# 3447                                                NaN                   NaN
# 3448  KOMPLEK RUKO MEGA GROSIR CEMPAKA MAS BLOK M no...  31.177.558.9-027.000
# 3449  Ruko Modernland Blok AR.1-2 Jln Jend.Sudirman ...  02.038.650.4-416.000
#
#      penawaran_pemenang                                      preprocessing
# 0                   NaN  tenaga ahli data driven kegiatan koordinasi se...
# 1                   NaN  tenaga ahli it analisa sistem kegiatan koordin...
# 2                   NaN  tenaga ahli senior monitoring evaluasi strateg...
# 3                   NaN  tenaga ahli senior perencanaan strategic natio...
# 4                   NaN  tenaga ahli muda bidang energy policy kegiatan...
# ...                 ...                                                ...
# 3445  Rp 226.369.000,00  pengadaan working furniture span class='label ...
# 3446  Rp 251.541.400,00  pengadaan living furniture span class='label l...
# 3447                NaN          pengadaan peralatan gerobak home industri
# 3448  Rp 594.000.000,00                       pengadaan modul aplikasi sib
# 3449  Rp 211.535.500,00  pengadaan pencetakan buku standar dokumen peng...
#
# [3450 rows x 22 columns]

# %%
raw_data_1.to_csv("LPSE LKPP + pemenang.csv",index=False)

# %% [markdown]
# # Raw Data 2 - SIRUP

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_weights_matrix = tfidf_vectorizer.fit_transform(raw_data_2['preprocessing'])
lda = LDA(n_components=20,n_jobs=-1)
lda_output = lda.fit_transform(tfidf_weights_matrix)
scaler = StandardScaler()
vectorScaler = scaler.fit_transform(lda_output)
vectorNormalize = normalize(vectorScaler)

# %%
kmeans_obj = KMeans(n_clusters=20, random_state=50)
kmeans_obj.fit(vectorNormalize)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=20, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=50, tol=0.0001, verbose=0)

# %%
visualizer_kmeans = InterclusterDistance(kmeans_obj, random_state = 50)
visualizer_kmeans.fit(vectorNormalize)
visualizer_kmeans.finalize()
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\manifold\mds.py:421: UserWarning: The MDS API has changed. ``fit`` now constructs an dissimilarity matrix from data. To use a custom dissimilarity matrix, set ``dissimilarity='precomputed'``.
#   warnings.warn("The MDS API has changed. ``fit`` now constructs an"

# %%
visualizer_kmeans_silhouette = SilhouetteVisualizer(kmeans_obj, color='yellowbrick')
visualizer_kmeans_silhouette.fit(vectorNormalize)
visualizer_kmeans_silhouette.show()

# %%
labels = kmeans_obj.labels_
silhouette_score = metrics.silhouette_score(vectorNormalize, labels, metric='euclidean')
silhouette_score
# Out:
# 0.7231653465119717

# %%
result_clustering = kmeans_obj.predict(vectorNormalize)

# %%
raw_data_2['kategori_kmeans'] = result_clustering
raw_data_2
# Out:
#       Unnamed: 0  idBulan              metode  \
# 0              0       10        E-Purchasing
# 1              1       10        E-Purchasing
# 2              2        4  Pengadaan Langsung
# 3              3        1  Pengadaan Langsung
# 4              4       12  Pengadaan Langsung
# ...          ...      ...                 ...
# 1430        1430        1        Dikecualikan
# 1431        1431        1              Tender
# 1432        1432        1             Seleksi
# 1433        1433        1        Dikecualikan
# 1434        1434        1        Dikecualikan
#
#                                                    nama  \
# 0                       Pengadaan Lemari Besi Fireproof
# 1                       Pengadaan Lemari Besi Fireproof
# 2                               Pengadaan Kursi Pejabat
# 3                             Belanja Bahan Pakai Habis
# 4                        Pengadaan Frame Acrilik Poster
# ...                                                 ...
# 1430  Belanja Jasa Akomodasi Pelatihan Imam Masjid A...
# 1431     Belanja Modal Pengadaan Alat Pemadam Kebakaran
# 1432                           Review pola PSDA Tahap 1
# 1433      Belanja Jasa Akomodasi Imam Masjid Angkatan V
# 1434     Belanja Jasa Akomodasi Imam Masjid Angkatan IV
#
#                                              instansi  \
# 0                                Kementerian Keuangan
# 1                                Kementerian Keuangan
# 2            Pemerintah Daerah Kabupaten Buton Tengah
# 3                        Pemerintah Daerah Kota Depok
# 4                               Kementerian Kesehatan
# ...                                               ...
# 1430        Pemerintah Daerah Provinsi Sumatera Barat
# 1431      Pemerintah Daerah Provinsi Kalimantan Timur
# 1432  Kementerian Pekerjaan Umum dan Perumahan Rakyat
# 1433        Pemerintah Daerah Provinsi Sumatera Barat
# 1434        Pemerintah Daerah Provinsi Sumatera Barat
#
#                                lokasi               jenis       waktu  \
# 0                                   -              Barang  2023-10-01
# 1                                   -              Barang  2023-10-01
# 2                                   -              Barang  2023-04-01
# 3                                   -              Barang  2021-01-01
# 4                                   -              Barang  2020-12-01
# ...                               ...                 ...         ...
# 1430                                -        Jasa Lainnya  2020-01-01
# 1431  Kalimantan Timur-Paser (Kab.),             Barang,   2020-01-01
# 1432      Jawa Barat-Bandung (Kota),   Jasa Konsultansi,   2020-01-01
# 1433                                -        Jasa Lainnya  2020-01-01
# 1434                                -        Jasa Lainnya  2020-01-01
#
#       idMetode        id       pagu  idJenisPengadaan  \
# 0            9  22319671   23000000                 1
# 1            9  22319671   23000000                 1
# 2            8  20854093    5000000                 1
# 3            8  20376353   10513000                 1
# 4            8  22867952  120000000                 1
# ...        ...       ...        ...               ...
# 1430        16  22421624   56000000                 4
# 1431        13  22139846  938000000                 0
# 1432        15  22744714  494680000                 0
# 1433        16  22424242   56000000                 4
# 1434        16  22424197   56000000                 4
#
#                                             satuanKerja  \
# 0     DIREKTORAT JENDERAL PENGELOLAAN PEMBIAYAAN DAN...
# 1     DIREKTORAT JENDERAL PENGELOLAAN PEMBIAYAAN DAN...
# 2     DINAS KOMUNIKASI INFORMATIKA STATISTIK DAN PER...
# 3        DINAS KETAHANAN PANGAN PERTANIAN DAN PERIKANAN
# 4     SEKRETARIAT DIREKTORAT JENDERAL PELAYANAN KESE...
# ...                                                 ...
# 1430  BIRO BINA MENTAL DAN KESEJAHTERAAN RAKYAT SETD...
# 1431                                    Dinas Kehutanan
# 1432                 BALAI BESAR WILAYAH SUNGAI CITARUM
# 1433  BIRO BINA MENTAL DAN KESEJAHTERAAN RAKYAT SETD...
# 1434  BIRO BINA MENTAL DAN KESEJAHTERAAN RAKYAT SETD...
#
#                                           preprocessing  kategori_kmeans
# 0                       pengadaan lemari besi fireproof                0
# 1                       pengadaan lemari besi fireproof                0
# 2                               pengadaan kursi pejabat                7
# 3                             belanja bahan pakai habis               15
# 4                        pengadaan frame acrilik poster                8
# ...                                                 ...              ...
# 1430  belanja jasa akomodasi pelatihan imam masjid a...               12
# 1431     belanja modal pengadaan alat pemadam kebakaran               16
# 1432                           review pola psda tahap 1               17
# 1433      belanja jasa akomodasi imam masjid angkatan v               12
# 1434     belanja jasa akomodasi imam masjid angkatan iv               12
#
# [1435 rows x 15 columns]

# %%
raw_data_2.to_csv("data sirup update.csv",index=False)
